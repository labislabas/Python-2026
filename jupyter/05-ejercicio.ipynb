# %% [markdown]
# **Contexto del problema**

# %% [markdown]
# La direccion General de Aguas (DGA) de la Region de los lagos necesita analizar el comportamiento del caudal del rio Gamboa tras un frente de mal tiempo. Como ingenieros se les ha encomendado procesar datos de medicion de caudal (en metro cubicos por segundo, $m^3$) tomados de forma automatizada cada 1 hora durante un turno de 8 horas.
#
# Requirimientos del ejercicio:
# Escribir un codigo en jupyter notebook utilizando dos funciones definifdas (def) que cumpla las siguientes especificaciones.
#
# 1.Funcion procesar_caudal:
# -no debe recibir parametros de entrada .
# -utilizar un arreglo unidimensional de numpy para generar secuencia de horas del 1 al 8.
# -Utilzar una lista para almacenar los caudales registrados.
# -Construir y devolver un DataFrame de pandas que contenga dos columnas estructuradas: 'Hora' y 'Caudal (m3/s)'
#
# 2.Visualizar_curva(dataframe)
# -Debe recibir como parametro el dataframe generado por la funcion anterior.
# -Utilizando Matplotlib , generar un gtafico de lineas ara observar la curva de crecida del rio.
# -El grafico debe incorporar
#         -Una linea con marcadores en forma de diamante o circulo en cada medicion (marker = 'o')
#         -Un titulo descriptivo: 'Monitoreo de caudal rio gambioa'
#         -Etiquetas en los ejes x: 'Tiempo (horas)' | ejes y: Caudal (m^3/s)
#
# 3.Bloque principal
# -Realizar
# caudales = [12.5, 14.2, 18.1, 22.8, 25.5, 21.0, 17.5, 15.3]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def procesar_caudal():
    horas = np.arange(1,9)      # Array = [1,2,3,4,5,6,7,8]
    caudales = [12.5, 14.2, 18.1, 22.8, 25.5, 21.0, 17.5, 15.3]

    data = {
        'Hora' : horas,
        'Caudal' : caudales
    }
    # Transformando un diccionario a data frame
    df = pd.DataFrame(data)
    return df

# %%
def visualizar_curva(dataFrame):
    fig, ax = plt.subplots()            # ax = axes

    ax.plot(dataFrame['Hora'], dataFrame['Caudal'], marker = 'o', color = 'green', linestyle = '-')
    ax.set_title('Monitoreo de Caudal Rio Gamboa')
    ax.set_xlabel('Tiempo (Horas)')
    ax.set_ylabel('Caudal (m^3/s)')

    ax.grid(True)

# %%
df_hidrologia = procesar_caudal()
visualizar_curva(df_hidrologia)
plt.show()
